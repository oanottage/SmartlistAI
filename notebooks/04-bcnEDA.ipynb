# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
os.chdir('/Users/oanottage/Desktop/BTS/Data Science Foundations/DSFinal/')

# %%
df = pd.read_csv('data/external/BCNDataset/2021_padro_ocupacio_mitjana.csv')

# %%
df.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2021               1  Ciutat Vella           1
# 1  2021               1  Ciutat Vella           2
# 2  2021               1  Ciutat Vella           3
# 3  2021               1  Ciutat Vella           4
# 4  2021               2      Eixample           5
#
#                                Nom_Barri  Poblacio  Domicilis  \
# 0                               el Raval     48688      17298
# 1                         el Barri Gòtic     22850       6571
# 2                         la Barceloneta     15125       6927
# 3  Sant Pere, Santa Caterina i la Ribera     23009      10071
# 4                          el Fort Pienc     33445      12782
#
#    Ocupacio_mitjana_(persones_ per_domicili)
# 0                                       2.81
# 1                                       3.48
# 2                                       2.18
# 3                                       2.28
# 4                                       2.62

# %%
df.groupby("Nom_Districte").sum()
# Out:
#                        Any  Codi_Districte  Codi_Barri  Poblacio  Domicilis  \
# Nom_Districte
# Ciutat Vella          8084               4          10    109672      40867
# Eixample             12126              12          45    269349     111779
# Gràcia               10105              30         150    123276      52701
# Horta-Guinardó       22231              77         418    173944      69956
# Les Corts             6063              12          60     81576      32780
# Nou Barris           26273             104         650    173552      66897
# Sant Andreu          14147              63         420    151537      59678
# Sant Martí           20210             100         685    241181      94907
# Sants-Montjuïc       16168              24         116    187026      74280
# Sarrià-Sant Gervasi  12126              30         147    149201      56218
#
#                      Ocupacio_mitjana_(persones_ per_domicili)
# Nom_Districte
# ...

# %%
df['ratio_people/poblacio'] = df["Ocupacio_mitjana_(persones_ per_domicili)"]/df.Poblacio*100

# %%
df_district_info = df.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)

# %%
df_district_info.to_csv("data/processed/district_info.csv")

# %%
df2 = pd.read_csv('data/external/BCNDataset/2017_padro_ocupacio_mitjana.csv')

# %%
df2['ratio_people/poblacio'] = df2['Ocupacio_mitjana_(persones_ per_domicili)']/df2.Poblacio*100
df2.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
# Out:
# /var/folders/gy/mhj_p09j1m14zw460p7wfy6nztk25_/T/ipykernel_94588/361311054.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
#                        Any  Codi_Districte  Codi_Barri  Poblacio  Domicilis  \
# Nom_Districte
# Nou Barris           26273             104         650    173552      66897
# Horta-Guinardó       22231              77         418    173944      69956
# Sants-Montjuïc       16168              24         116    187026      74280
# Sant Andreu          14147              63         420    151537      59678
# Sant Martí           20210             100         685    241181      94907
# Sarrià-Sant Gervasi  12126              30         147    149201      56218
# ...

# %%
df3 = pd.read_csv('data/external/BCNDataset/2017_padro_ocupacio_mitjana.csv')

# %%
df3['ratio_people/poblacio'] = df3['Ocupacio_mitjana_(persones_ per_domicili)']/df3.Poblacio*100
df3.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
# Out:
# /var/folders/gy/mhj_p09j1m14zw460p7wfy6nztk25_/T/ipykernel_94588/1662626158.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
#                        Any  Codi_Districte  Codi_Barri  Poblacio  Domicilis  \
# Nom_Districte
# Nou Barris           26221             104         650    166805      66312
# Horta-Guinardó       22187              77         418    169187      69388
# Sants-Montjuïc       16136              24         116    182354      73887
# Sant Andreu          14119              63         420    147693      59174
# Sant Martí           20170             100         685    236163      94395
# Sarrià-Sant Gervasi  12102              30         147    149734      56344
# ...

# %%
df4 = pd.read_csv('data/external/BCNDataset/2022_padro_nivell_academic_per_sexe.csv')
df4.head(20)
# Out:
#      Any  Codi_Districte Nom_Districte  Codi_Barri       Nom_Barri   Sexe  \
# 0   2022               1  Ciutat Vella           1        el Raval  Dones
# 1   2022               1  Ciutat Vella           1        el Raval  Dones
# 2   2022               1  Ciutat Vella           1        el Raval  Dones
# 3   2022               1  Ciutat Vella           1        el Raval  Dones
# 4   2022               1  Ciutat Vella           1        el Raval  Dones
# 5   2022               1  Ciutat Vella           1        el Raval  Dones
# 6   2022               1  Ciutat Vella           1        el Raval  Homes
# 7   2022               1  Ciutat Vella           1        el Raval  Homes
# 8   2022               1  Ciutat Vella           1        el Raval  Homes
# 9   2022               1  Ciutat Vella           1        el Raval  Homes
# 10  2022               1  Ciutat Vella           1        el Raval  Homes
# 11  2022               1  Ciutat Vella           1        el Raval  Homes
# ...

# %%
df_ingreso_persona = pd.read_csv('data/external/BCNDataset/2019_atles_renda_bruta_persona.csv')
df_ingreso_persona
# Out:
#        Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0     2019               1  Ciutat Vella           1
# 1     2019               1  Ciutat Vella           1
# 2     2019               1  Ciutat Vella           1
# 3     2019               1  Ciutat Vella           1
# 4     2019               1  Ciutat Vella           1
# ...    ...             ...           ...         ...
# 1063  2019              10    Sant Martí          73
# 1064  2019              10    Sant Martí          65
# 1065  2019              10    Sant Martí          69
# 1066  2019              10    Sant Martí          69
# 1067  2019              10    Sant Martí          71
#
#                                          Nom_Barri  Seccio_Censal  \
# 0                                         el Raval              1
# 1                                         el Raval              2
# 2                                         el Raval              3
# ...

# %%
df_ingreso_persona['avg_salary'] = df_ingreso_persona.iloc[:,6]

# %%
df_ingreso_persona.sort_values('avg_salary', ascending = False).head(60)
# Out:
#       Any  Codi_Districte        Nom_Districte  Codi_Barri  \
# 426  2019               5  Sarrià-Sant Gervasi          24
# 429  2019               5  Sarrià-Sant Gervasi          24
# 395  2019               4            Les Corts          21
# 453  2019               5  Sarrià-Sant Gervasi          26
# 460  2019               5  Sarrià-Sant Gervasi          26
# 398  2019               4            Les Corts          21
# 399  2019               4            Les Corts          21
# 428  2019               5  Sarrià-Sant Gervasi          24
# 427  2019               5  Sarrià-Sant Gervasi          24
# 425  2019               5  Sarrià-Sant Gervasi          24
# 404  2019               5  Sarrià-Sant Gervasi          23
# 424  2019               5  Sarrià-Sant Gervasi          24
# 406  2019               5  Sarrià-Sant Gervasi          23
# 408  2019               5  Sarrià-Sant Gervasi          23
# 452  2019               5  Sarrià-Sant Gervasi          26
# ...

# %%
df.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
# Out:
# /var/folders/gy/mhj_p09j1m14zw460p7wfy6nztk25_/T/ipykernel_94588/606765902.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Nom_Districte").sum().sort_values('ratio_people/poblacio',ascending = False)
#                        Any  Codi_Districte  Codi_Barri  Poblacio  Domicilis  \
# Nom_Districte
# Nou Barris           26286             104         650    170736      66964
# Horta-Guinardó       22242              77         418    172109      70151
# Sants-Montjuïc       16176              24         116    183770      74502
# Sant Andreu          14154              63         420    149826      60002
# Sant Martí           20220             100         685    239465      95544
# Sarrià-Sant Gervasi  12132              30         147    148201      56430
# ...

# %%
df_ingreso_persona.groupby("Nom_Districte").mean().sort_values('avg_salary',ascending = False)
# Out:
# /var/folders/gy/mhj_p09j1m14zw460p7wfy6nztk25_/T/ipykernel_94588/919767440.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_ingreso_persona.groupby("Nom_Districte").mean().sort_values('avg_salary',ascending = False)
#                         Any  Codi_Districte  Codi_Barri  Seccio_Censal  \
# Nom_Districte
# Sarrià-Sant Gervasi  2019.0             5.0   25.173469      49.500000
# Les Corts            2019.0             4.0   19.508772      29.473684
# Eixample             2019.0             2.0    7.601156      87.000000
# Gràcia               2019.0             6.0   30.678161      44.954023
# Sant Martí           2019.0            10.0   68.489796      76.448980
# Horta-Guinardó       2019.0             7.0   37.186992      62.000000
# ...

# %%
df_gini_index = pd.read_csv('BCNDataset/2019_atles_renda_index_gini.csv')
df_gini_index
# Out:
#        Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0     2019               1  Ciutat Vella           1
# 1     2019               1  Ciutat Vella           1
# 2     2019               1  Ciutat Vella           1
# 3     2019               1  Ciutat Vella           1
# 4     2019               1  Ciutat Vella           1
# ...    ...             ...           ...         ...
# 1063  2019              10    Sant Martí          73
# 1064  2019              10    Sant Martí          65
# 1065  2019              10    Sant Martí          69
# 1066  2019              10    Sant Martí          69
# 1067  2019              10    Sant Martí          71
#
#                                          Nom_Barri  Seccio_Censal  Index_Gini
# 0                                         el Raval              1        35.6
# 1                                         el Raval              2        38.2
# 2                                         el Raval              3        36.8
# ...

# %%
df_gini_index.groupby("Nom_Districte").mean().sort_values('Index_Gini',ascending = False)
# Out:
# /var/folders/gy/mhj_p09j1m14zw460p7wfy6nztk25_/T/ipykernel_94588/943442754.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_gini_index.groupby("Nom_Districte").mean().sort_values('Index_Gini',ascending = False)
#                         Any  Codi_Districte  Codi_Barri  Seccio_Censal  \
# Nom_Districte
# Sarrià-Sant Gervasi  2019.0             5.0   25.173469      49.500000
# Ciutat Vella         2019.0             1.0    2.296296      28.074074
# Eixample             2019.0             2.0    7.601156      87.000000
# Les Corts            2019.0             4.0   19.508772      29.473684
# Gràcia               2019.0             6.0   30.678161      44.954023
# Sants-Montjuïc       2019.0             3.0   14.931624      61.461538
# ...
